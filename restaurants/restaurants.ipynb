# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('FoodServiceData.csv')

# %%
df.head()
# Out:
#    EstablishmentID  InspectionID Ins_TypeDesc          EstablishmentName  \
# 0            72438       1579836      REGULAR  GORDON FOOD SERVICE STORE
# 1            72438       1579837      REGULAR  GORDON FOOD SERVICE STORE
# 2            34272       1579862      REGULAR           WHITE CASTLE #17
# 3            92244       1579944      REGULAR           8 TASTE OF CHINA
# 4           108032       1579945      REGULAR          SOUL FOOD EXPRESS
#
#    PlaceName                 Address  Address2        City State    Zip  \
# 0        NaN  641 S HURSTBOURNE PKWY       NaN  LOUISVILLE    KY  40222
# 1        NaN  641 S HURSTBOURNE PKWY       NaN  LOUISVILLE    KY  40222
# 2        NaN       3705 BARDSTOWN RD       NaN  LOUISVILLE    KY  40218
# 3        NaN           1167 S 4TH ST       NaN  LOUISVILLE    KY  40203
# 4        NaN            418 W OAK ST       NaN  LOUISVILLE    KY  40203
#
#                      TypeDescription       InspectionDate  score Grade  \
# ...

# %%
df.shape
# Out:
# (7400, 16)

# %%
grade_a = df[df.Grade == "A"]

grade_a.count()
# Out:
# EstablishmentID      4795
# InspectionID         4795
# Ins_TypeDesc         4795
# EstablishmentName    4795
# PlaceName               0
# Address              4795
# Address2                0
# City                 4795
# State                4795
# Zip                  4795
# TypeDescription      4795
# InspectionDate       4795
# score                4795
# Grade                4795
# NameSearch           4795
# Intersection            0
# dtype: int64

# %%
grade_b = df[df.Grade == "B"]

grade_b.count()
# Out:
# EstablishmentID      30
# InspectionID         30
# Ins_TypeDesc         30
# EstablishmentName    30
# PlaceName             0
# Address              30
# Address2              0
# City                 30
# State                30
# Zip                  30
# TypeDescription      30
# InspectionDate       30
# score                30
# Grade                30
# NameSearch           30
# Intersection          0
# dtype: int64

# %%
grade_sorted = df.dropna(subset=['score', 'Grade']).sort_values(by='score', ascending=True)
grade_sorted
# Out:
#       EstablishmentID  InspectionID Ins_TypeDesc      EstablishmentName  \
# 6687           100533       1639075      REGULAR               EL NOPAL
# 3571            96041       1613238      REGULAR                HOOTERS
# 5494           100280       1632435      REGULAR          TIME FOR THAI
# 4280            98855       1602045      REGULAR                 EL REY
# 1467            92726       1614624      REGULAR               ACAPULCO
# ...               ...           ...          ...                    ...
# 3790            73000       1623978      REGULAR       PUZZLES FUN DOME
# 3802            84374       1613900      REGULAR       FAT JIMMY'S FOUR
# 3811            32722       1596997      REGULAR  CARTER DUVALLE SCHOOL
# 3778            99345       1619824      REGULAR     PLEASE & THANK YOU
# 3714            60776       1621436      REGULAR        MEIJER #160 GAS
#
#       PlaceName                  Address  Address2        City State    Zip  \
# ...

# %%
x = df.score

y = sorted(df.InspectionDate)

plt.scatter(x, y)

plt.yticks(df.InspectionDate[::1000])

plt.show()

# %%
bins = [70, 80, 90, 100]

plt.hist(df.score, bins = bins)

plt.xticks = bins

plt.show()
